# %%
#configure jupyter notebook to run SQL commands
# %load_ext sql

# %%
#connect to database
#database is a sqlite database file stored locally, 
#it is a open source db, refer to README for download location
# %sql sqlite:////Users/admin/personal_projs/sql_practice/data/Chinook_Sqlite.sqlite
# Out:
# 'Connected: @/Users/admin/personal_projs/sql_practice/data/Chinook_Sqlite.sqlite'

# %% [markdown]
# **Aggregate functions**

# %%
# %%sql result <<
# SELECT COUNT(*) AS total_employees,
# FROM Employee;
# Out:
#  * sqlite:////Users/admin/personal_projs/sql_practice/data/Chinook_Sqlite.sqlite
# (sqlite3.OperationalError) near "FROM": syntax error
# [SQL: SELECT COUNT(*) AS total_employees, FROM Employee;]
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
result
# Out:
# [(8,)]

# %%
# %%sql result <<
# SELECT SUM(Milliseconds)/60000 AS total_minutes,
# AVG(Milliseconds)/1000 AS avg_seconds,
# MIN(UnitPrice) AS cheapest_unit,
# MAX(UnitPrice) AS priciest_unit
# FROM Track;
# Out:
#  * sqlite:////Users/admin/personal_projs/sql_practice/data/Chinook_Sqlite.sqlite
# Done.
# Returning data to local variable result

# %%
result
# Out:
# [(22979, 393.59921210391093, 0.99, 1.99)]

# %% [markdown]
# **GROUP BY**

# %%
# %%sql result <<
# SELECT TrackId, Composer
# FROM Track
# GROUP BY Composer;
# Out:
#  * sqlite:////Users/admin/personal_projs/sql_practice/data/Chinook_Sqlite.sqlite
# Done.
# Returning data to local variable result

# %%
result
# Out:
# [(3499, None),
#  (2109, 'A. F. Iommi, W. Ward, T. Butler, J. Osbourne'),
#  (1908, 'A. Jamal'),
#  (415, 'A.Bouchard/J.Bouchard/S.Pearlman'),
#  (2589, 'A.Isbell/A.Jones/O.Redding'),
#  (22, 'AC/DC'),
#  (3427, 'Aaron Copland'),
#  (3357, 'Aaron Goldberg'),
#  (453, 'Ace Frehley'),
#  (3159, 'Acyi Marques/Arlindo Bruz/Braço, Beto Sem/Zeca Pagodinho'),
#  (3158, 'Acyr Marques/Arlindo Cruz/Franco'),
#  (567, 'Adalto Magalha/Lourenco'),
#  (2974, 'Adam Clayton, Bono, Larry Mullen & The Edge'),
#  (2948, 'Adam Clayton, Bono, Larry Mullen, The Edge'),
#  (1424, 'Addie William Jones/Nat Jones'),
#  (1383, 'Adrian Smith'),
#  (1357, 'Adrian Smith/Bruce Dickinson'),
#  (1251, 'Adrian Smith/Bruce Dickinson/Nicko McBrain'),
#  (1364, 'Adrian Smith/Bruce Dickinson/Steve Harris'),
#  (1389, 'Adrian Smith/Clive Burr/Steve Harris'),
#  (1394, 'Adrian Smith/Steve Harris'),
#  (1371, 'Adrian Smith; Bruce Dickinson'),
#  (1377, 'Adrian Smith; Bruce Dickinson; Steve Harris'),
# ...

# %% [markdown]
# **HAVING**

# %%
# %%sql result <<
# SELECT SUM(UnitPrice) AS total_price, Composer
# FROM Track
# GROUP BY Composer
# HAVING total_price > 10;
# Out:
#  * sqlite:////Users/admin/personal_projs/sql_practice/data/Chinook_Sqlite.sqlite
# Done.
# Returning data to local variable result

# %%
result
# Out:
# [(1181.2200000000073, None),
#  (10.89, 'Adam Clayton, Bono, Larry Mullen & The Edge'),
#  (10.89, 'Adam Clayton, Bono, Larry Mullen, The Edge'),
#  (12.870000000000001, 'Alanis Morissette & Glenn Ballard'),
#  (15.840000000000002, 'Anthony Kiedis, Flea, John Frusciante, and Chad Smith'),
#  (18.81, 'Anthony Kiedis/Chad Smith/Flea/John Frusciante'),
#  (13.860000000000001, 'Audioslave/Chris Cornell'),
#  (24.74999999999999, 'Bill Berry-Peter Buck-Mike Mills-Michael Stipe'),
#  (10.89, 'Bill Berry/Michael Stipe/Mike Mills/Peter Buck'),
#  (19.799999999999997, 'Billie Joe Armstrong -Words Green Day -Music'),
#  (30.68999999999998, 'Billy Corgan'),
#  (10.89, 'Bob Rock/James Hetfield/Kirk Hammett/Lars Ulrich'),
#  (11.88, 'Bono, The Edge, Adam Clayton, and Larry Mullen'),
#  (11.88, 'Bono/Clayton, Adam/Mullen Jr., Larry/The Edge'),
#  (13.860000000000001, 'Brian Eno, Bono, Adam Clayton, The Edge & Larry Mullen Jnr.'),
#  (10.89, 'Caetano Veloso e Gilberto Gil'),
# ...

# %% [markdown]
# **DISTINCT**

# %%
# %%sql result <<
# SELECT COUNT(DISTINCT Composer) AS total_composers
# FROM Track;
# Out:
#  * sqlite:////Users/admin/personal_projs/sql_practice/data/Chinook_Sqlite.sqlite
# Done.
# Returning data to local variable result

# %%
result
# Out:
# [(852,)]

# %% [markdown]
# **Case**

# %%
# %%sql result <<
# SELECT Composer,
# CASE
# WHEN COUNT(*) < 5 THEN "low"
# WHEN COUNT(*) < 10 THEN "mid"
# ELSE "high"
# END AS track_count
# FROM Track
# GROUP BY Composer;
# Out:
#  * sqlite:////Users/admin/personal_projs/sql_practice/data/Chinook_Sqlite.sqlite
# Done.
# Returning data to local variable result

# %%
result
# Out:
# [(None, 'high'),
#  ('A. F. Iommi, W. Ward, T. Butler, J. Osbourne', 'low'),
#  ('A. Jamal', 'low'),
#  ('A.Bouchard/J.Bouchard/S.Pearlman', 'low'),
#  ('A.Isbell/A.Jones/O.Redding', 'low'),
#  ('AC/DC', 'mid'),
#  ('Aaron Copland', 'low'),
#  ('Aaron Goldberg', 'low'),
#  ('Ace Frehley', 'low'),
#  ('Acyi Marques/Arlindo Bruz/Braço, Beto Sem/Zeca Pagodinho', 'low'),
#  ('Acyr Marques/Arlindo Cruz/Franco', 'low'),
#  ('Adalto Magalha/Lourenco', 'low'),
#  ('Adam Clayton, Bono, Larry Mullen & The Edge', 'high'),
#  ('Adam Clayton, Bono, Larry Mullen, The Edge', 'high'),
#  ('Addie William Jones/Nat Jones', 'low'),
#  ('Adrian Smith', 'mid'),
#  ('Adrian Smith/Bruce Dickinson', 'mid'),
#  ('Adrian Smith/Bruce Dickinson/Nicko McBrain', 'low'),
#  ('Adrian Smith/Bruce Dickinson/Steve Harris', 'mid'),
#  ('Adrian Smith/Clive Burr/Steve Harris', 'low'),
#  ('Adrian Smith/Steve Harris', 'mid'),
#  ('Adrian Smith; Bruce Dickinson', 'low'),
# ...
